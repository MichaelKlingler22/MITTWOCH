# %%
Grundlagen-Python-Variablen
Der Umgang mit Variablen ist einfach und bei der Programmierung dennoch wichtig.
Im Beispiel darunter eine Zahl zu einer Variable.

# %%
a=1
b=2
c=a+b
print(c)
# Out:
# 3
